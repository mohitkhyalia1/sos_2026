# %% [markdown]
# #Print function

# %%
print('Machine Learning')
# Out:
# Machine Learning

# %%
print('Machine Learning'+' Projects')
# Out:
# Machine Learning Projects

# %%
print(8)
# Out:
# 8

# %%
print(3+5)
# Out:
# 8

# %%
type(8)
# Out:
# int

# %%
type(8.2)
# Out:
# float

# %%
type('human')
# Out:
# str

# %% [markdown]
# Constant & variables

# %%
super_hero = "iron men"

# %%
print(super_hero)
# Out:
# iron men

# %%
super_hero = 'caption america'

# %%
print(super_hero)
# Out:
# caption america

# %%
hero1, hero2, hero3 = 'man1', 'man2', 'man3'

# %%
print(hero1)
print(hero2)
print(hero3)
# Out:
# man1
# man2
# man3

# %% [markdown]
# use ctrl+/ to comment complete cell

# %%
# number_1 = int(input('Enter the first number: '))
# number_2 = float(input('Enter the second number: '))

# sum = number_1 + number_2
# print(sum)

# %% [markdown]
# change the data type

# %%
number = 1

# %%
type(number)
# Out:
# int

# %%
print(float(number))
# Out:
# 1.0

# %% [markdown]
# #Basic Data Types in Python:
#
#
#
# 1.   Integer
# 2.   Floating Point
#
# 3. Complex
#
# 4. Boolean
#
# 5. String

# %%
#integer
a=8
print(a)
type(a)
# Out:
# 8
# int

# %%
#float
b=2.4
print(b)
type(b)
# Out:
# 2.4
# float

# %%
#complex number
c= 3 + 2j
print(c)
type(c)
# Out:
# (3+2j)
# complex

# %% [markdown]
# conversion of one type to another

# %%
#int to float
x=10
print(x)
type(x)
y=float(x)
print(y)
type(y)
# Out:
# 10
# 10.0
# float

# %%
type(x)
# Out:
# int

# %%
#float to int
w=3.7
z=int(w)
print(z)
type(z)
# Out:
# 3
# int

# %%
print(w)
type(w)
# Out:
# 3.7
# float

# %% [markdown]
# #Boolean

# %%
a= True
print(a)
type(a)
# Out:
# True
# bool

# %%
b=False
print(b)
type(b)
# Out:
# False
# bool

# %%
c= 7<9
print(c)
type(c)
# Out:
# True
# bool

# %% [markdown]
# #String

# %%
my_string = 'Python Besics '
print(my_string)
type(my_string)
y= 3*my_string
print(y)
# Out:
# Python Besics
# Python Besics Python Besics Python Besics

# %%
type(y)
# Out:
# str

# %%
print(my_string[0:-5])
# Out:
# Python Be

# %%
print(my_string[1:8:2])
# Out:
# yhnB

# %%
total_character = len(my_string)
print(total_character)
# Out:
# 14

# %%
#string connection
word_1 = "Machine "
Word_2 = 'Learning'
print(word_1 + Word_2)
# Out:
# Machine Learning

# %% [markdown]
# #Types of Objects in Python:
#
# 1. Immutable Objects
# 2. Mutable Objects
#
# Immutable Objects:
#
# 1. int
# 2. float
# 3. string
# 4. bool
# 5. tuple
#
# Mutable Objects:
#
# 1. List
# 2. Set
# 3. Dictionary

# %% [markdown]
# #list

# %%
#list should be included in squre bracket
my_list = [1,2,3,4]
print(my_list)
type(my_list)
# Out:
# [1, 2, 3, 4]
# list

# %%
#list can be multiple data type
my_list=[1,3.4,'book',False]
print(my_list)
type(my_list)
# Out:
# [1, 3.4, 'book', False]
# list

# %% [markdown]
# List are Mutable => Changeable

# %%
#add elements to List
my_list.append('hello')
print(my_list)
# Out:
# [1, 3.4, 'book', False, 'hello']

# %%
#prit element of list using index
print(my_list[4])
print(my_list[1])
# Out:
# hello
# 3.4

# %%
#list allow duplicate values
my_list.append(1)
print(my_list)
# Out:
# [1, 3.4, 'book', False, 'hello', 1]

# %%
#number of elements in a list
print(len(my_list))
# Out:
# 6

# %%
#initiating an empty list
list1=[]
print(list1)
# Out:
# []

# %%
list1.append(4)
print(list1)
# Out:
# [4]

# %%
# delete an item in list
list_2 = [1,2,3,4,5,'Machine Learning',6]
del list_2[4]
print(list_2)
# Out:
# [1, 2, 3, 4, 'Machine Learning', 6]

# %%
#join two list
list_3 = ['!',2,3,3,5]
list_4 = list_2 +list_3
print(list_4)
# Out:
# [1, 2, 3, 4, 'Machine Learning', 6, '!', 2, 3, 3, 5]

# %% [markdown]
# #Tuple

# %%
tuple_1=(1,3,4,5,6,5,'hello',True)
print(tuple_1)
type(tuple_1)
# Out:
# (1, 3, 4, 5, 6, 5, 'hello', True)
# tuple

# %%
#tuple allowes repetation of values and multiple datatypes

# %%
#conversion of tuple to list
my_list = list(tuple_1)
print(my_list)
type(my_list)
# Out:
# [1, 3, 4, 5, 6, 5, 'hello', True]
# list

# %%
print(tuple_1[2])
print(tuple_1[6])
# Out:
# 4
# hello

# %% [markdown]
# Tuples are Immutable => Unchangebale

# %%
my_tuple = (1,2,3,4,5)
print(my_tuple)
#my_tuple.append(2)
#my_tuple[2] = 4
# These doesn't support
print(len(my_tuple))
# Out:
# (1, 2, 3, 4, 5)
# 5

# %% [markdown]
# #Set

# %%
# set are inclosed in {}
# set does not allow duplicate values
set_1 = {1,2,3,5,6,7,5,6,8,'hello'}
print(set_1)
type(set_1)
# Out:
# {1, 2, 3, 5, 6, 7, 8, 'hello'}
# set

# %%
# print(set_1[2])
# 'set' object is not subscriptable

# %% [markdown]
# Sets are unordered collections, so they use `.add()` instead of `.append()`. Their modification methods return `None` because they update in-place.

# %%
print(set_1)
set_2 = set_1.add(9)
#set_2 = set_1.append(10)     'set' object has no attribute 'append'
print(set_2)
print(set_1)
set_3 = set_1
print(set_3)
# Out:
# {1, 2, 3, 5, 6, 7, 8, 'hello'}
# None
# {1, 2, 3, 5, 6, 7, 8, 9, 'hello'}
# {1, 2, 3, 5, 6, 7, 8, 9, 'hello'}

# %%
#convert set to list
list_1 = list(set_1)
print(list_1)
# Out:
# [1, 2, 3, 5, 6, 7, 8, 9, 'hello']

# %% [markdown]
# #Dictionary

# %%
dictionary_1 = {'name': 'mohit','age':'20','school':'iitb'}
print(dictionary_1)
type(dictionary_1)
# Out:
# {'name': 'mohit', 'age': '20', 'school': 'iitb'}
# dict

# %%
print(dictionary_1['name'])
# Out:
# mohit

# %%
dictionary_2 = {'name': 'mohit','age':'20','school':'iitb','name': 'mohit','age':'20','school':'iitb'}
print(dictionary_2)
#it don't allow duplicate values
# Out:
# {'name': 'mohit', 'age': '20', 'school': 'iitb'}

# %% [markdown]
# #Operators in Python:
#
# 1. Arithmetic Operators
# 2. Assignment Operators
# 3. Comparison Operators
# 4. Logical Operators
# 5. Identity Operators
# 6. Membership Operators

# %% [markdown]
# 1. Arithmetic Operation

# %%
num_1 = 20
num_2 = 10
print(num_1 + num_2)
# Out:
# 30
